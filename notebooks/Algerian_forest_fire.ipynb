# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel("Algerian_forest_fires_dataset_UPDATE.xlsx",header=1)

# %%
dataset
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes
# 0    0.5  not fire
# 1    0.4  not fire
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# # Data cleaning

# %%
# missing_values

# %%
dataset.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
dataset[dataset.isnull().any(axis = 1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI   FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 123   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire     NaN

# %% [markdown]
#  this dataset contains two regions
#  we add new column ("region")

# %%
dataset.loc[:122,"region"] = 0
dataset.loc[122:,"region"] = 1

# %%
dataset
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 0    0.5  not fire     0.0
# ...

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#     Classes  region
# 0  not fire     0.0
# 1  not fire     0.0
# 2  not fire     0.0
# 3  not fire     0.0
# 4  not fire     0.0

# %%
dataset.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 242  26     9  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 243  27     9  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 244  28     9  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 245  29     9  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 246  30     9  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#       Classes  region
# 242      fire     1.0
# 243  not fire     1.0
# 244  not fire     1.0
# 245  not fire     1.0
# 246  not fire     1.0

# %%
dataset["region"] = dataset["region"].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  region       247 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.1+ KB

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#     Classes  region
# 0  not fire       0
# 1  not fire       0
# 2  not fire       0
# 3  not fire       0
# 4  not fire       0

# %% [markdown]
# removing null values

# %%
df = dataset.dropna().reset_index(drop = True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# region         0
# dtype: int64

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 0    0.5  not fire       0
# ...

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes  region
# 122  FWI  Classes       1

# %%
df.iloc[[121]]
# Out:
#     day month  year Temperature  RH  Ws Rain FFMC  DMC   DC  ISI  BUI  FWI  \
# 121  30     9  2012          25  78  14  1.4   45  1.9  7.5  0.2  2.4  0.1
#
#       Classes  region
# 121  not fire       0

# %%
df.iloc[[123]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 123   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#       Classes  region
# 123  not fire       1

# %%
# so we have to remove row(122)
df = df.drop(122,axis = 0)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 0    0.5  not fire       0
# ...

# %%
df.reset_index(drop = True)
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 0    0.5  not fire       0
# ...

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 0    0.5  not fire       0
# ...

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 123   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#       Classes  region
# 123  not fire       1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  region       243 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 29.4+ KB

# %% [markdown]
# we have to change column datatype

# %%
df[['day','month','year','Temperature','RH','Ws']] = df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 23.7+ KB

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 23.7+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# now we save this clean dataset

# %%
df.to_csv("algerian_forest_fire_clean_dataset.csv")

# %% [markdown]
# # Exloratory Data Analysis

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  region
# 239  6.5      fire       1
# 240  0.0  not fire       1
# 241  0.2  not fire       1
# 242  0.7  not fire       1
# 243  0.5  not fire       1

# %%
df.value_counts("Classes")
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df["Classes"] = np.where(df["Classes"].str.contains("not fire"),0,1)
# we are encoding categories in Classes feature
# not fire - 0
# fire - 1

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes  region
# ...

# %%
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes  region
# 239  6.5        1       1
# 240  0.0        0       1
# 241  0.2        0       1
# 242  0.7        0       1
# 243  0.5        0       1

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes  region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# 4  0.5        0       0

# %%
df.value_counts("Classes")
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# Graphs

# %%
percentage_of_classes = df["Classes"].value_counts(normalize=True)*100

# %%
percentage_of_classes
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
plt.pie(x=percentage_of_classes,labels=["Fire","Not fire"],autopct="%1.1f%%")
plt.title("Pie chart of classes")
plt.show()

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes  region
# ...

# %% [markdown]
# correlation

# %%
df_1 = df.drop(["day","month","year"],axis = 1)

# %%
df_1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df_1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(data = df_1.corr(),annot= True)
# Out:
# <Axes: >

# %%
sns.boxplot(df_1["FWI"],color="Green")
# with help of box plot we find out outliers
# Out:
# <Axes: ylabel='FWI'>

# %% [markdown]
# monthly fire analysis

# %%
# for region = 1
sns.countplot(data = df[df["region"] ==0],x = "month",hue="Classes")
plt.title("Sidi-bel abbes region")
plt.show()

# 1 = Fire
# 0 = Not fire

# %%
# for region 2 
sns.countplot(data =df[df["region"]==1],x = "month",hue = "Classes")
plt.title("bejaia region")
plt.show()
# 1 = Fire
# 0 = Not fire

# %% [markdown]
# # Observations

# %% [raw]
# it is observed that in both regions most forest fire occur in the month of august
# in sidi bel abbes region least forest fire occur in the month of september
# in bejaia region least forest fire occur in the month of june

# %%
df_1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_1.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      region
# 239       1
# 240       1
# 241       1
# 242       1
# 243       1

# %%
x =df_1.drop("FWI",axis = 1) # independent feature
y = df_1["FWI"]              # dependent feature

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 239    6.5
# 240    0.0
# 241    0.2
# 242    0.7
# 243    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
x
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
# train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (182, 11) (61, 11) (182,) (61,)

# %% [markdown]
# # Feature Selection

# %% [raw]
# we check for mulicollinearity - in multicollinearity we check correlation between 2 independent feature nd if corelation is high
# it means both features are same and then from those two features we select only 1 feature for model training

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    region
# ...

# %%
sns.heatmap(data = X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
X_train.corr().columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'Classes', 'region'],
#       dtype='object')

# %%
def correlation(dataset,*threshold_value):
    corr_col = set()                                # this is an empty set because we dont want repeated column names
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold_value:
                col_name = corr_matrix.columns[i]
                corr_col.add(col_name)
    return corr_col

# %%
corr_feature = correlation(X_train,0.85)

# %%
corr_feature
# Out:
# {'BUI', 'DC'}

# %%
# drop feature from both(train and test data) which is greater than 0.85 
X_train.drop(corr_feature,axis = 1,inplace=True)
X_test.drop(corr_feature,axis=1,inplace=True)

# %%
print(X_train.shape,X_test.shape)   # now there are only 9 independent features
# Out:
# (182, 9) (61, 9)

# %% [markdown]
# # Feature Scaling

# %% [raw]
# in Feature Scaling we scale down the values so that convergence is fast

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(X_train_scaled)
# Out:
# [[-0.84284248  0.78307967  1.29972026 ... -0.62963326 -1.10431526
#   -0.98907071]
#  [-0.30175842  0.64950844 -0.59874754 ... -0.93058524 -1.10431526
#    1.01105006]
#  [ 2.13311985 -2.08870172 -0.21905398 ...  2.7271388   0.90553851
#    1.01105006]
#  ...
#  [-1.9250106   0.9166509   0.54033314 ... -1.06948615 -1.10431526
#   -0.98907071]
#  [ 0.50986767 -0.21870454  0.16063958 ...  0.5973248   0.90553851
#    1.01105006]
#  [-0.57230045  0.98343651  2.05910739 ... -0.86113478 -1.10431526
#   -0.98907071]]

# %%
print(X_train)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI  Classes  region
# 97            29  74  19   0.1  75.8   3.6   2.1        0       0
# 142           31  72  14   0.2  60.2   3.8   0.8        0       1
# 193           40  31  15   0.0  94.2  22.5  16.6        1       1
# 68            32  60  18   0.3  77.1  11.3   2.2        0       0
# 119           32  47  14   0.7  77.5   7.1   1.8        0       0
# ..           ...  ..  ..   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   0.2        0       0
# 14            28  80  17   3.1  49.4   3.0   0.4        0       0
# 92            25  76  17   7.2  46.0   1.3   0.2        0       0
# 180           34  59  16   0.0  88.1  19.5   7.4        1       1
# 102           30  77  21   1.8  58.5   1.9   1.1        0       0
#
# [182 rows x 9 columns]

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(X_train)
plt.subplot(1,2,2)
sns.boxplot(X_train_scaled)

# scaling - scaled out data almost in same range
# Out:
# <Axes: >

# %% [markdown]
# # Model training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([ 8.22340505e+00,  7.75252922e+00, -2.54117416e-01,  4.35589319e+00,
#         6.69135945e+00,  1.36202538e+00,  2.03864111e+00,  7.79328670e+00,
#         1.72547890e+00,  3.33158516e+00,  4.13723043e-01,  9.75001593e+00,
#         9.33180880e+00,  1.70522541e+01,  1.85133518e+01,  1.24250301e+00,
#         1.85818589e+00, -2.19341618e-02,  7.18794479e+00,  3.06137615e+00,
#         1.43702876e+00,  2.31135272e-01,  6.57677437e+00,  3.31761969e-01,
#         2.10846121e+01,  5.11915298e+00,  5.93220317e+00,  9.80969813e+00,
#        -6.46764212e-02,  9.81330986e+00,  6.64475980e+00, -4.53909646e-01,
#         1.04015941e+01,  1.45820244e+01,  1.47807316e+00,  4.33773546e-01,
#         2.04109845e+00,  6.08454570e+00, -4.65467631e-01, -3.05185642e-01,
#         6.68439528e+00,  1.79727675e+00,  8.59237254e+00, -2.66715046e-01,
#         1.54439592e+01,  8.32647113e+00,  8.25849719e+00,  1.42038134e+00,
# ...

# %%
from sklearn.metrics import mean_absolute_error  # because outliers present in our data
from sklearn.metrics import r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

# %%
mae
# Out:
# 0.5468236465249978

# %%
score
# Out:
# 0.9847657384266951

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

# %%
mae
# Out:
# 1.133175994914409

# %%
score
# Out:
# 0.9492020263112388

# %% [markdown]
# # Ridge regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

# %%
mae
# Out:
# 0.5642305340105715

# %%
score
# Out:
# 0.9842993364555512

# %% [markdown]
# # Elastic net regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
el_net = ElasticNet()
el_net.fit(X_train_scaled,y_train)
y_pred = el_net.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

# %%
mae
# Out:
# 1.8822353634896005

# %%
score
# Out:
# 0.8753460589519703

# %% [raw]
# now we create pickle file - any object in python can be pickeled so that it can be saved on hard disk
# (here this model is need to be  saved on hard disk with help of pickle and
# we deploy our model istead running this code again
# and when we give input to our model it will predict output)

# %%
import pickle
pickle.dump(scaler,open("scaler.pkl","wb"))
pickle.dump(ridge,open("ridge.pkl","wb"))
